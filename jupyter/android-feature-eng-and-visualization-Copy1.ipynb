# %%
import pandas as pd
import numpy as np
import glob
import os
from matplotlib import pyplot
import seaborn as sbn
import seaborn as sbn
from mlxtend.frequent_patterns import apriori, association_rules
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from mpl_toolkits.mplot3d import Axes3D
from sklearn.feature_selection import SelectKBest, chi2, f_regression, mutual_info_regression, f_classif
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, StackingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from imblearn.under_sampling import RandomUnderSampler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from imblearn.over_sampling import SMOTE

# %%
pd. set_option("display.max_columns", None)

# %%
df = pd.read_csv('./android-fitness-and-medical-cleaned-data(no-duplicate).csv')

# %% [markdown]
# #### FEATURE ENGINNERING

# %% [markdown]
# **Rating Count Categorization**
#
# 1+, 5+, 10+, 50+, 100+, 500+, 1,000+, 5,000+, 10,000+, 50,000+, 100,000+, 500,000+, 1,000,000+, 5,000,000, 10,000,000+, 50,000,000+

# %%
def determine_if_app_is_free_or_not(price):
    if (price > 0):
        return 'PAID'
    return 'FREE'

# %%
def grade_app_with_rating(app_rating):
    if ((app_rating >=0) and (app_rating <2.5)):
        return 'BAD'
    if ((app_rating >=2.5) and (app_rating <3.0)):
        return 'FAIR'
    if ((app_rating >=3.0) and (app_rating <4.0)):
        return 'GOOD'
    if ((app_rating >=4.0) and (app_rating <4.5)):
        return 'VERY GOOD'
    if (app_rating >=4.5):
        return 'EXCELLENT'

# %%
def grade_app_with_rating2(app_rating, rating_count):
    if ((app_rating >=0) and (app_rating <2.5)):
        return 'BAD'
    if ((app_rating >=2.5) and (app_rating <3.0)):
        return 'FAIR'
    if ((app_rating >=3.0) and (app_rating <4.0)):
        if rating_count < 50:
            return 'FAIR'
        return 'GOOD'
    if ((app_rating >=4.0) and (app_rating <4.5)):
        if rating_count < 50:
            return 'FAIR'
        elif rating_count >=50 and rating_count <100:
            return 'GOOD' 
        else:
            return 'VERY GOOD'
    if (app_rating >=4.5):
        if rating_count < 50:
            return 'FAIR'
        elif rating_count >=50 and rating_count <100:
            return 'GOOD'
        elif rating_count >=100 and rating_count < 500:
            return 'VERY GOOD'
        else:
            return 'EXCELLENT'

# %%
def create_rating_count_range(rating_count):
    if (rating_count >=1 and rating_count<5):
        return '1+'
    if (rating_count >=5 and rating_count<10):
        return '5+'
    if (rating_count >=10 and rating_count<50):
        return '10+'
    if (rating_count >=50 and rating_count<100):
        return '50+'
    if (rating_count >=100 and rating_count<500):
        return '100+'
    if (rating_count >=500 and rating_count<1000):
        return '500+'
    if (rating_count >=1000 and rating_count<5000):
        return '1,000+'
    if (rating_count >=5000 and rating_count<10000):
        return '5,000+'
    if (rating_count >=10000 and rating_count<50000):
        return '10,000+'
    if (rating_count >=50000 and rating_count<100000):
        return '50,000+'
    if (rating_count >=100000 and rating_count<500000):
        return '100,000+'
    if (rating_count >=500000 and rating_count<1000000):
        return '500,000+'
    if (rating_count >=1000000 and rating_count<5000000):
        return '1,000,000+'
    if (rating_count >=5000000 and rating_count<10000000):
        return '5,000,000+'
    if (rating_count >=10000000 and rating_count<50000000):
        return '10,000,000+'
    if (rating_count >=50000000 and rating_count<100000000):
        return '50,000,000+'
    return 0

# %%
def is_app_updated_in_2022(last_updated_date, released_date, version):
    if (version == '1.0.0'):
        return False
    if (last_updated_date == released_date):
        return False
    if '2022' in last_updated_date:
        return True
    return False

# %%
def is_app_ever_updated(last_updated_date, released_date, version):
    if (version == '1.0.0'):
        return False
    if (last_updated_date == released_date):
        return False
    return True

# %%
def is_app_version_device_dependent(version):
    return version == 'Varies with device'

# %%
def is_app_available_in_multiple_countries(count):
    return count > 1

# %%
def create_price_category(price):
    if (price >0.0 and price<1.0):
        return '0+'
    if (price >=1 and price<5):
        return '1+'
    if (price >=5 and price<10):
        return '5+'
    if (price >=10 and price<50):
        return '10+'
    if (price >=50 and price<100):
        return '50+'
    if (price >=100 and price<500):
        return '100+'
    if (price >=500 and price<1000):
        return '500+'
    return 0

# %%
def perform_feature_engineering(df):
    df['Service Type'] = df['Price'].apply(determine_if_app_is_free_or_not)
    df['is_available_in_multiple_countries'] = df['Country Count'].apply(is_app_available_in_multiple_countries)
    df['is_version_app_dependent'] = df['Version'].apply(is_app_version_device_dependent)
    df['Rating Count Range'] = df['Rating Count'].apply(create_rating_count_range)
    df['Price Category'] = df['Price'].apply(create_price_category)
#     df['App Grade'] = df['Average Rating'].apply(grade_app_with_rating)
    for index in df.index:
        link = df.at[index, 'App Link']
        last_updated_date = df.at[index, 'Last Updated']
        released_date = df.at[index, 'Released Date']
        version = df.at[index, 'Version']
        rating_count = df.at[index, 'Rating Count']
        average_rating = df.at[index, 'Average Rating']
        df.at[index, 'is_updated_this_year'] = is_app_updated_in_2022(last_updated_date, released_date, version)
        df.at[index, 'is_app_ever_updated'] = is_app_ever_updated(last_updated_date, released_date, version)
        df.at[index, 'App Grade'] = grade_app_with_rating2(average_rating, rating_count)

# %%
perform_feature_engineering(df)

# %%
df[df['Average Rating'] > 4].sort_values(by='Rating Count', ascending=True)
# Out:
#      Unnamed: 0                        App Name Age Rating  Price  \
# 707        4979              SJA First Aid Fast     PEGI 3   0.00
# 711        4989                       OrthoFlow     PEGI 3   4.99
# 677        4914                        CFR PLUS     PEGI 3   0.00
# 678        4915      Foundation Doctor Handbook     PEGI 3   2.99
# 449        1616                  Clarity Locums     PEGI 3   0.00
# ..          ...                             ...        ...    ...
# 937        6084             Six Pack in 30 Days     PEGI 3   0.00
# 916        6063  MyFitnessPal - Calorie Counter     PEGI 3   0.00
# 953        6100  Flo Menstrual & Period Tracker     PEGI 3   0.00
# 944        6091     Home Workout - No Equipment     PEGI 3   0.00
# 897        6044  Period Calendar Period Tracker     PEGI 3   0.00
#
#      InApp Purchase  Average Rating  Rating Count  \
# 707           False             5.0             7
# 711           False             4.6            12
# 677            True             4.4            15
# 678           False             4.8            17
# 449           False             4.4            35
# ..              ...             ...           ...
# 937            True             4.9       2130000
# 916            True             4.4       2510000
# 953            True             4.7       2630000
# 944            True             4.9       2840000
# 897            True             4.9       6710000
#
#                                               App Link  Last Updated  \
# 707  https://play.google.com/store/apps/details?id=...   May 6, 2022
# 711  https://play.google.com/store/apps/details?id=...  Jul 15, 2018
# 677  https://play.google.com/store/apps/details?id=...  Jul 26, 2021
# 678  https://play.google.com/store/apps/details?id=...   Aug 4, 2021
# 449  https://play.google.com/store/apps/details?id=...  Jun 14, 2022
# ..                                                 ...           ...
# 937  https://play.google.com/store/apps/details?id=...  Jun 19, 2022
# 916  https://play.google.com/store/apps/details?id=...  Jun 22, 2022
# 953  https://play.google.com/store/apps/details?id=...  Jun 22, 2022
# 944  https://play.google.com/store/apps/details?id=...  Apr 27, 2022
# 897  https://play.google.com/store/apps/details?id=...  Jun 10, 2022
#
#     Released Date     Downloads             Version    Application Type  \
# 707  Mar 28, 2022        5,000+               1.0.3             MEDICAL
# 711  Jul 15, 2018        1,000+               1.0.0             MEDICAL
# 677  Jun 22, 2020        1,000+               1.0.7             MEDICAL
# 678  Jul 19, 2019        1,000+                18.0             MEDICAL
# 449  Nov 24, 2019       10,000+                7.41             MEDICAL
# ..            ...           ...                 ...                 ...
# 937   Jan 9, 2018  100,000,000+               1.1.1  HEALTH AND FITNESS
# 916  Apr 26, 2010  100,000,000+  Varies with device  HEALTH AND FITNESS
# 953  Apr 12, 2016   50,000,000+  Varies with device  HEALTH AND FITNESS
# 944   Nov 8, 2017  100,000,000+               1.1.8  HEALTH AND FITNESS
# 897  Mar 16, 2012  100,000,000+  Varies with device  HEALTH AND FITNESS
#
#      Country Count                                          Countries  \
# 707              1                                                 GB
# 711              1                                                 GB
# 677              1                                                 GB
# 678              1                                                 GB
# 449              1                                                 IE
# ..             ...                                                ...
# 937             50  SE,FR,GB,GF,GP,DK,GR,PL,RE,PM,NL,AT,MC,MT,NO,B...
# 916             45  SE,FR,GB,GF,GP,DK,GR,PL,RE,PM,NL,AT,MT,NO,BL,L...
# 953             50  SE,FR,GB,GF,GP,DK,GR,PL,RE,PM,NL,AT,MC,MT,NO,B...
# 944             50  SE,FR,GB,GF,GP,DK,GR,PL,RE,PM,NL,AT,MC,MT,NO,B...
# 897             43  SE,GF,GP,DK,GR,PL,RE,PM,AT,MC,MT,BL,LU,MQ,MF,C...
#
#     Service Type  is_available_in_multiple_countries  \
# 707         FREE                               False
# 711         PAID                               False
# 677         FREE                               False
# 678         PAID                               False
# 449         FREE                               False
# ..           ...                                 ...
# 937         FREE                                True
# 916         FREE                                True
# 953         FREE                                True
# 944         FREE                                True
# 897         FREE                                True
#
#      is_version_app_dependent Rating Count Range Price Category  \
# 707                     False                 5+              0
# 711                     False                10+             1+
# 677                     False                10+              0
# 678                     False                10+             1+
# 449                     False                10+              0
# ..                        ...                ...            ...
# 937                     False         1,000,000+              0
# 916                      True         1,000,000+              0
# 953                      True         1,000,000+              0
# 944                     False         1,000,000+              0
# 897                      True         5,000,000+              0
#
#     is_updated_this_year is_app_ever_updated  App Grade
# 707                 True                True       FAIR
# 711                False               False       FAIR
# 677                False                True       FAIR
# 678                False                True       FAIR
# 449                 True                True       FAIR
# ..                   ...                 ...        ...
# 937                 True                True  EXCELLENT
# 916                 True                True  VERY GOOD
# 953                 True                True  EXCELLENT
# 944                 True                True  EXCELLENT
# 897                 True                True  EXCELLENT
#
# [476 rows x 23 columns]

# %% [markdown]
# #### VISUALIZATION

# %%
df[:5]
# Out:
#    Unnamed: 0                       App Name Age Rating  Price  \
# 0           0                  TraceTogether     PEGI 3   0.00
# 1           1         Blood Pressure Analyze     PEGI 3   0.00
# 2           2  Monash University FODMAP diet     PEGI 3   5.60
# 3           3  Squeezy: NHS Pelvic Floor App     PEGI 3   2.99
# 4           4   Muscle Trigger Point Anatomy     PEGI 3   2.69
#
#    InApp Purchase  Average Rating  Rating Count  \
# 0           False             2.9         57100
# 1            True             3.9         12300
# 2           False             3.5          2470
# 3           False             4.6          3250
# 4           False             4.5          1590
#
#                                             App Link  Last Updated  \
# 0  https://play.google.com/store/apps/details?id=...  May 31, 2022
# 1  https://play.google.com/store/apps/details?id=...   Sep 9, 2021
# 2  https://play.google.com/store/apps/details?id=...  Jan 18, 2022
# 3  https://play.google.com/store/apps/details?id=...   Mar 4, 2019
# 4  https://play.google.com/store/apps/details?id=...  Jul 30, 2019
#
#   Released Date   Downloads             Version Application Type  \
# 0   Mar 9, 2020  1,000,000+              2.14.2          MEDICAL
# 1   Apr 1, 2019  1,000,000+               1.3.2          MEDICAL
# 2   Nov 6, 2013    100,000+               3.0.9          MEDICAL
# 3  Sep 17, 2014     50,000+  Varies with device          MEDICAL
# 4  Jan 27, 2011     50,000+               2.4.8          MEDICAL
#
#    Country Count                                          Countries  \
# 0             31  FO,HR,SM,GI,EE,SI,GL,SK,PF,SJ,IS,VA,BG,WF,LI,A...
# 1             32  FO,HR,SM,GI,EE,SI,GL,SK,PF,SJ,IS,VA,BG,WF,LI,A...
# 2             46  FO,PT,HR,IT,DE,FI,EE,HU,SI,ES,GL,IE,RO,SK,PF,S...
# 3             45  FO,PT,HR,SM,GI,FI,EE,HU,SI,GL,IE,RO,SK,PF,SJ,I...
# 4             42  FO,PT,HR,IT,DE,FI,EE,HU,SI,GL,IE,RO,SK,PF,SJ,I...
#
#   Service Type  is_available_in_multiple_countries  is_version_app_dependent  \
# 0         FREE                                True                     False
# 1         FREE                                True                     False
# 2         PAID                                True                     False
# 3         PAID                                True                      True
# 4         PAID                                True                     False
#
#   Rating Count Range Price Category is_updated_this_year is_app_ever_updated  \
# 0            50,000+              0                 True                True
# 1            10,000+              0                False                True
# 2             1,000+             5+                 True                True
# 3             1,000+             1+                False                True
# 4             1,000+             1+                False                True
#
#    App Grade
# 0       FAIR
# 1       GOOD
# 2       GOOD
# 3  EXCELLENT
# 4  EXCELLENT

# %%
def draw_histogram(data, x_axis_title, height=5, aspect=1.6):
    sbn.displot(data, color = 'darkblue', kind='hist', height=5, aspect=1.6)
    pyplot.xlabel(x_axis_title)
    pyplot.ylabel('Density')

def draw_count_plot(data, x_column, x_label, y_label, fig_size=(8,6), order=None, hue=None):
    sbn.set(rc = {'figure.figsize':fig_size})
    sbn.countplot(data=data, x=x_column, order=order, color='#1C8BAD', hue=hue )
    pyplot.xlabel(x_label)
    pyplot.ylabel(y_label)
    pyplot.xticks(rotation=45, horizontalalignment='right',fontweight='light',fontsize='large')
    pyplot.show()

def set_plot_labels(x_label, y_label, font_size):
    pyplot.xlabel(x_label)
    pyplot.ylabel(y_label)
    pyplot.xticks(rotation=45, horizontalalignment='right', fontweight='light', fontsize=font_size)

# %%
def draw_count_plot_with_annot(data, x_column, x_label, y_label, fig_size=(8,6),annotCount=False, order=None, 
                               hue=None, palette=None):
    sbn.set(rc = {'figure.figsize':fig_size})
    sbndataplot = sbn.countplot(data=data, x=x_column, order=order, color='#1C8BAD', hue=hue, palette=palette)
    for p in sbndataplot.patches:
        if annotCount == True:
            height = p.get_height()
            if (pd.isna(height) == True):
                height = 0
            else:
                height = int(height)
            sbndataplot.annotate(height, 
                       (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha = 'center', va = 'center', 
                       xytext = (0, 9), 
                       textcoords = 'offset points')
        else:
            sbndataplot.annotate(format(p.get_height()/len(data)*100, '.2f')+'%', 
                       (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha = 'center', va = 'center', 
                       xytext = (0, 9), 
                       textcoords = 'offset points')
    pyplot.xlabel(x_label)
    pyplot.ylabel(y_label)
    pyplot.xticks(rotation=45, horizontalalignment='right',fontweight='light',fontsize='large')
    pyplot.tight_layout(rect=(0, 0, 1, 1.4))
    pyplot.show()

# %%
rating_count_range_order = [0, '1+', '5+', '10+', '50+', '100+', '500+', '1,000+', '5,000+', '10,000+', '50,000+', 
                            '100,000+', '500,000+', '1,000,000+', '5,000,000+']
price_range_order = [0, '0+', '1+', '5+', '10+', '50+', '100+', '500+']
app_grade_order = ['BAD', 'FAIR', 'GOOD', 'VERY GOOD', 'EXCELLENT']

# %% [markdown]
# #### Price influence

# %%
df['Price'].max(), df['Price'].min()
# Out:
# (109.99, 0.0)

# %%
df['Price Category'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1566    False
# 1567    False
# 1568    False
# 1569    False
# 1570    False
# Name: Price Category, Length: 1571, dtype: bool

# %%
draw_count_plot(df, 'Price Category', 'Price Category', 'Count', fig_size=(8,8), 
               order=price_range_order)

# %%
sbn.scatterplot(data=df, y='Price', x='Average Rating')
fig = pyplot.gcf()
fig.set_size_inches(12, 8)

# %%
sbn.scatterplot(data=df, y='Price', x='Average Rating', hue='Service Type', legend='full')
fig = pyplot.gcf()
fig.set_size_inches(12, 8)

# %%
eng_supp_app_grade_plot = sbn.FacetGrid(df, col="App Grade", col_wrap=3, height=5, aspect=1.0,
                                        col_order=app_grade_order)
eng_supp_app_grade_plot.map(sbn.countplot, "Service Type", order=['FREE', 'PAID'])

# %%
eng_supp_app_grade_plot = sbn.FacetGrid(df, col="App Grade", col_wrap=3, height=5, aspect=1.0,
                                        col_order=app_grade_order)
eng_supp_app_grade_plot.map(sbn.countplot, "is_updated_this_year", order=[True, False])

# %%
sbn.scatterplot(data=df, x='Average Rating', y='Price', hue='is_updated_this_year', legend='full')
fig = pyplot.gcf()
fig.set_size_inches(12, 8)

# %%
eng_supp_app_grade_plot = sbn.FacetGrid(df, col="Service Type", col_wrap=2, height=5, aspect=1.0)
eng_supp_app_grade_plot.map(sbn.countplot, "InApp Purchase")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/axisgrid.py:670: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
eng_supp_app_grade_plot = sbn.FacetGrid(df, col="App Grade", col_wrap=3, height=5, aspect=1.0,
                                        col_order=app_grade_order)
eng_supp_app_grade_plot.map(sbn.countplot, "InApp Purchase", order=[True, False])

# %% [markdown]
# #### Application Rating effect on the app?

# %%
eng_supp_app_grade_plot = sbn.FacetGrid(df, col="App Grade", col_wrap=2, height=5, aspect=2.5,
                                        col_order=app_grade_order)
eng_supp_app_grade_plot.map(sbn.countplot, "Rating Count Range", order=rating_count_range_order)

# %%
sbn.scatterplot(data=df, y='Rating Count', x='Price', hue='is_updated_this_year', legend='full')
fig = pyplot.gcf()
fig.set_size_inches(12, 8)

# %%
draw_count_plot(df, 'Rating Count Range', 'Average Rating Count', 'Application Count', fig_size=(10,8))

# %%
sbn.scatterplot(data=df, y='Rating Count', x='Average Rating', hue='is_updated_this_year', legend='full')
fig = pyplot.gcf()
fig.set_size_inches(12, 8)

# %%
eng_supp_app_grade_plot = sbn.FacetGrid(df, col="InApp Purchase", col_wrap=1, height=5, aspect=3.0)
eng_supp_app_grade_plot.map(sbn.countplot, "Rating Count Range", order=rating_count_range_order)

# %% [markdown]
# #### Application Type

# %%
draw_count_plot(df, 'Application Type', 'Application Type', 'Application Count', fig_size=(2,6))

# %%
eng_supp_app_grade_plot = sbn.FacetGrid(df, col="Application Type", col_wrap=1, height=5, aspect=3.5)
eng_supp_app_grade_plot.map(sbn.countplot, "Rating Count Range", order=rating_count_range_order)

# %%
eng_supp_app_grade_plot = sbn.FacetGrid(df, col="Application Type", col_wrap=2, height=4, aspect=1.5)
eng_supp_app_grade_plot.map(sbn.countplot, "is_app_ever_updated", order=[True, False])

# %%
eng_supp_app_grade_plot = sbn.FacetGrid(df, col="Application Type", col_wrap=2, height=4, aspect=1.5)
eng_supp_app_grade_plot.map(sbn.countplot, "is_updated_this_year", order=[True, False])

# %%
eng_supp_app_grade_plot = sbn.FacetGrid(df, col="Application Type" ,col_wrap=1, 
                                        height=10, aspect=3.5)
eng_supp_app_grade_plot.map(sbn.countplot, "Rating Count Range", order=rating_count_range_order)

# %%
eng_supp_app_grade_plot = sbn.FacetGrid(df, col="Application Type", col_wrap=2, height=4, aspect=1.5)
eng_supp_app_grade_plot.map(sbn.countplot, "is_version_app_dependent", order=[True, False])

# %%
eng_supp_app_grade_plot = sbn.FacetGrid(df, col="App Grade", col_wrap=2, height=5, aspect=2.5,
                                        col_order=app_grade_order)
eng_supp_app_grade_plot.map(sbn.countplot, "is_version_app_dependent", order=[True, False])

# %%
eng_supp_app_grade_plot = sbn.FacetGrid(df, col="Application Type", col_wrap=2, height=4, aspect=1.5)
eng_supp_app_grade_plot.map(sbn.countplot, "is_available_in_multiple_countries", order=[True, False])

# %% [markdown]
# #### ASSOCIATION RULE MINING

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1571 entries, 0 to 1570
# Data columns (total 23 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Unnamed: 0                          1571 non-null   int64
#  1   App Name                            1571 non-null   object
#  2   Age Rating                          1571 non-null   object
#  3   Price                               1571 non-null   float64
#  4   InApp Purchase                      1571 non-null   bool
#  5   Average Rating                      1571 non-null   float64
#  6   Rating Count                        1571 non-null   int64
#  7   App Link                            1571 non-null   object
#  8   Last Updated                        1571 non-null   object
#  9   Released Date                       1317 non-null   object
#  10  Downloads                           1571 non-null   object
#  11  Version                             1570 non-null   object
#  12  Application Type                    1571 non-null   object
#  13  Country Count                       1571 non-null   int64
#  14  Countries                           1571 non-null   object
#  15  Service Type                        1571 non-null   object
#  16  is_available_in_multiple_countries  1571 non-null   bool
#  17  is_version_app_dependent            1571 non-null   bool
#  18  Rating Count Range                  1571 non-null   object
#  19  Price Category                      1571 non-null   object
#  20  is_updated_this_year                1571 non-null   object
#  21  is_app_ever_updated                 1571 non-null   object
#  22  App Grade                           1571 non-null   object
# dtypes: bool(3), float64(2), int64(3), object(15)
# memory usage: 250.2+ KB

# %%
def convert_consequent_to_str(consq):
    return str(consq).replace("frozenset({'", '').replace("})", '').replace("'", '')

def convert_antecedent_to_str(antecedent):
    antecedent = str(antecedent).replace("frozenset({'", '').replace("})", '').replace("'", '')
    return antecedent

def prepare_apriori_columns(df, column_list):
    apriori_df = list()
    for col in column_list:
        apriori_df.append(pd.get_dummies(df[col], prefix=col))
    apriori_df = pd.concat(apriori_df, axis=1)
    return apriori_df

def get_conditions_which_apps_are_most_likely_rated(min_support, min_threshold):
    apriori_df = prepare_apriori_columns(df,['Age Rating', 'InApp Purchase', 'Downloads',
                                                       'App Grade', 'is_app_ever_updated', 
                        'Service Type', 'is_available_in_multiple_countries', 'Rating Count Range',
                                             'is_updated_this_year', 'Price Category'] )
    rules = apriori(apriori_df, min_support=min_support, use_colnames=True)
    association_rules_df = association_rules(rules, metric='confidence', min_threshold=min_threshold)
    association_rules_df["antecedent_len"] = association_rules_df["antecedents"].apply(lambda x: len(x))
    association_rules_df["consequents_len"] = association_rules_df["consequents"].apply(lambda x: len(x))
    association_rules_df['antecedents'] = association_rules_df['antecedents'].apply(convert_antecedent_to_str)
    association_rules_df['consequents'] = association_rules_df['consequents'].apply(convert_consequent_to_str)
    association_rules_df.sort_values(by=['confidence'], ascending=False, inplace=True)
    return association_rules_df[(association_rules_df['consequents_len']==1) & 
                                (association_rules_df['antecedent_len']>1)]

# %%
def print_consequents_and_antecedents(df, consequent):
    filtered_df = df[df['consequents'].str.find(consequent) > -1]
    i = 1
    for index in filtered_df.index:
        if (i < 10):
            ants = filtered_df.at[index, 'antecedents']
            cons = filtered_df.at[index, 'consequents']
            support = filtered_df.at[index, 'support']
            conviction = filtered_df.at[index, 'conviction']
            confidence = filtered_df.at[index, 'confidence']
            print(f'{i}. {ants} => {cons} ({round(support,2), round(confidence,2), round(conviction,2)})')
            i = i + 1

# %%
association_df = get_conditions_which_apps_are_most_likely_rated(0.5, 0.5)

# %%
print_consequents_and_antecedents(association_df,'Service Type')
# Out:
# 1. is_updated_this_year_True, Price Category_0 => Service Type_FREE ((0.65, 1.0, inf))
# 2. is_available_in_multiple_countries_False, Price Category_0 => Service Type_FREE ((0.57, 1.0, inf))
# 3. is_available_in_multiple_countries_False, is_app_ever_updated_True, Price Category_0 => Service Type_FREE ((0.56, 1.0, inf))
# 4. is_app_ever_updated_True, Price Category_0 => Service Type_FREE ((0.82, 1.0, inf))
# 5. is_app_ever_updated_True, is_updated_this_year_True, Age Rating_PEGI 3, Price Category_0 => Service Type_FREE ((0.63, 1.0, inf))
# 6. is_app_ever_updated_True, is_updated_this_year_True, Price Category_0 => Service Type_FREE ((0.65, 1.0, inf))
# 7. is_available_in_multiple_countries_False, is_app_ever_updated_True, Age Rating_PEGI 3, Price Category_0 => Service Type_FREE ((0.55, 1.0, inf))
# 8. Age Rating_PEGI 3, Price Category_0 => Service Type_FREE ((0.81, 1.0, inf))
# 9. is_updated_this_year_True, Age Rating_PEGI 3, Price Category_0 => Service Type_FREE ((0.63, 1.0, inf))

# %%
print_consequents_and_antecedents(association_df,'App Grade')
# Out:
# 1. Rating Count Range_0, Age Rating_PEGI 3 => App Grade_BAD ((0.51, 1.0, inf))
# 2. is_app_ever_updated_True, Age Rating_PEGI 3 => App Grade_BAD ((0.52, 0.55, 0.99))

# %%
print_consequents_and_antecedents(association_df,'Age Rating')
# Out:
# 1. Rating Count Range_0, App Grade_BAD => Age Rating_PEGI 3 ((0.51, 0.98, 1.82))
# 2. is_app_ever_updated_True, App Grade_BAD => Age Rating_PEGI 3 ((0.52, 0.98, 1.71))
# 3. InApp Purchase_False, is_app_ever_updated_True => Age Rating_PEGI 3 ((0.57, 0.98, 1.68))
# 4. is_available_in_multiple_countries_False, is_app_ever_updated_True => Age Rating_PEGI 3 ((0.6, 0.97, 1.24))
# 5. is_available_in_multiple_countries_False, Service Type_FREE => Age Rating_PEGI 3 ((0.56, 0.97, 1.2))
# 6. is_available_in_multiple_countries_False, Service Type_FREE, Price Category_0 => Age Rating_PEGI 3 ((0.56, 0.97, 1.2))
# 7. is_available_in_multiple_countries_False, Price Category_0 => Age Rating_PEGI 3 ((0.56, 0.97, 1.2))
# 8. is_available_in_multiple_countries_False, is_app_ever_updated_True, Service Type_FREE, Price Category_0 => Age Rating_PEGI 3 ((0.55, 0.97, 1.17))
# 9. is_available_in_multiple_countries_False, is_app_ever_updated_True, Service Type_FREE => Age Rating_PEGI 3 ((0.55, 0.97, 1.17))

# %%
print_consequents_and_antecedents(association_df,'is_updated_this_year')
# Out:
# 1. Service Type_FREE, is_app_ever_updated_True, Age Rating_PEGI 3, Price Category_0 => is_updated_this_year_True ((0.63, 0.79, 1.37))
# 2. is_app_ever_updated_True, Age Rating_PEGI 3, Price Category_0 => is_updated_this_year_True ((0.63, 0.79, 1.37))
# 3. is_app_ever_updated_True, Age Rating_PEGI 3, Service Type_FREE => is_updated_this_year_True ((0.63, 0.79, 1.37))
# 4. is_app_ever_updated_True, Price Category_0 => is_updated_this_year_True ((0.65, 0.79, 1.34))
# 5. is_app_ever_updated_True, Service Type_FREE => is_updated_this_year_True ((0.65, 0.79, 1.34))
# 6. Service Type_FREE, is_app_ever_updated_True, Price Category_0 => is_updated_this_year_True ((0.65, 0.79, 1.34))
# 7. Age Rating_PEGI 3, Price Category_0 => is_updated_this_year_True ((0.63, 0.78, 1.27))
# 8. Service Type_FREE, Age Rating_PEGI 3, Price Category_0 => is_updated_this_year_True ((0.63, 0.78, 1.27))
# 9. Age Rating_PEGI 3, Service Type_FREE => is_updated_this_year_True ((0.63, 0.78, 1.27))

# %%
print_consequents_and_antecedents(association_df,'Price Category')
# Out:
# 1. is_available_in_multiple_countries_False, is_app_ever_updated_True, Service Type_FREE => Price Category_0 ((0.56, 1.0, inf))
# 2. is_updated_this_year_True, Age Rating_PEGI 3, Service Type_FREE => Price Category_0 ((0.63, 1.0, inf))
# 3. is_available_in_multiple_countries_False, Service Type_FREE => Price Category_0 ((0.57, 1.0, inf))
# 4. is_app_ever_updated_True, Service Type_FREE => Price Category_0 ((0.82, 1.0, inf))
# 5. is_app_ever_updated_True, is_updated_this_year_True, Age Rating_PEGI 3, Service Type_FREE => Price Category_0 ((0.63, 1.0, inf))
# 6. is_app_ever_updated_True, is_updated_this_year_True, Service Type_FREE => Price Category_0 ((0.65, 1.0, inf))
# 7. Age Rating_PEGI 3, Service Type_FREE => Price Category_0 ((0.81, 1.0, inf))
# 8. is_available_in_multiple_countries_False, is_app_ever_updated_True, Age Rating_PEGI 3, Service Type_FREE => Price Category_0 ((0.55, 1.0, inf))
# 9. is_available_in_multiple_countries_False, Age Rating_PEGI 3, Service Type_FREE => Price Category_0 ((0.56, 1.0, inf))

# %% [markdown]
# #### CLUSTERING

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1571 entries, 0 to 1570
# Data columns (total 23 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Unnamed: 0                          1571 non-null   int64
#  1   App Name                            1571 non-null   object
#  2   Age Rating                          1571 non-null   object
#  3   Price                               1571 non-null   float64
#  4   InApp Purchase                      1571 non-null   bool
#  5   Average Rating                      1571 non-null   float64
#  6   Rating Count                        1571 non-null   int64
#  7   App Link                            1571 non-null   object
#  8   Last Updated                        1571 non-null   object
#  9   Released Date                       1317 non-null   object
#  10  Downloads                           1571 non-null   object
#  11  Version                             1570 non-null   object
#  12  Application Type                    1571 non-null   object
#  13  Country Count                       1571 non-null   int64
#  14  Countries                           1571 non-null   object
#  15  Service Type                        1571 non-null   object
#  16  is_available_in_multiple_countries  1571 non-null   bool
#  17  is_version_app_dependent            1571 non-null   bool
#  18  Rating Count Range                  1571 non-null   object
#  19  Price Category                      1571 non-null   object
#  20  is_updated_this_year                1571 non-null   object
#  21  is_app_ever_updated                 1571 non-null   object
#  22  App Grade                           1571 non-null   object
# dtypes: bool(3), float64(2), int64(3), object(15)
# memory usage: 250.2+ KB

# %% [markdown]
# - Rating Count
# - Country Count
# - Price
# - Average Rating

# %%
def draw_elbow_graph(kmeans_df):
    wcss=[]
    for i in range(1,15):
        kmeans = KMeans(i)
        kmeans.fit(kmeans_df)
        wcss_iter = kmeans.inertia_
        wcss.append(wcss_iter)

    number_clusters = range(1,15)
    pyplot.subplot(2, 2, 1)
    pyplot.plot(number_clusters,wcss)
    pyplot.title('The Elbow title')
    pyplot.xlabel('Number of clusters')
    pyplot.ylabel('WCSS')
    fig = pyplot.gcf()
    fig.set_size_inches(24, 16)

# %%
def execute_kmeans(df, columns,n_cluster):
    standard_scaler = StandardScaler()
    kmeans_df = df[columns]
    kmeans_df_scaled = standard_scaler.fit_transform(kmeans_df)
    draw_elbow_graph(kmeans_df_scaled)
    kmeans = KMeans(n_clusters=n_cluster, random_state=42).fit(kmeans_df_scaled)
    labels = kmeans.predict(kmeans_df_scaled)
    centroids = kmeans.cluster_centers_
    kmeans_df_cluster = kmeans_df.copy()
    kmeans_df_cluster['cluster'] = labels
#     print(kmeans_df_cluster['cluster'].value_counts())
    if (len(columns) == 3):
        ax = pyplot.subplot(2, 2, 2, projection='3d')
        ax.scatter(kmeans_df_scaled[:,0], kmeans_df_scaled[:,1], kmeans_df_scaled[:,2] ,c=kmeans.labels_, 
                   cmap='rainbow',
               edgecolor='k', s=40, alpha = 0.5)
        ax.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1],
               kmeans.cluster_centers_[:,2], s = 300, c = 'r',
               marker='*', label = 'Centroid')
    elif (len(columns) == 4):
        ax = pyplot.subplot(2, 2, 2, projection='3d')
        ax.scatter(kmeans_df_scaled[:,0], kmeans_df_scaled[:,1], kmeans_df_scaled[:,2] , kmeans_df_scaled[:,3]
                   ,c=kmeans.labels_, 
                   cmap='rainbow',
               edgecolor='k', s=40, alpha = 0.5)
        ax.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1],
               kmeans.cluster_centers_[:,2], kmeans.cluster_centers_[:,3], s = 300, c = 'r',
               marker='*', label = 'Centroid')
    else:
        ax = pyplot.subplot(2, 2, 2)
        ax.scatter(kmeans_df_scaled[:, 0],kmeans_df_scaled[:, 1],
            c=kmeans.labels_, cmap='rainbow')
    
    fig = pyplot.gcf()
    fig.set_size_inches(20, 16)
    return kmeans_df_cluster

# %%
kmeans_df_cluster_df1 = execute_kmeans(df, ['Price', 'Average Rating', 'Rating Count'], 5)

# %%
kmeans_df_cluster_df1['cluster'].value_counts()
# Out:
# 0    838
# 3    695
# 1     21
# 2     16
# 4      1
# Name: cluster, dtype: int64

# %%
kmeans_df_cluster_df1.groupby(by='cluster').min()
# Out:
#          Price  Average Rating  Rating Count
# cluster
# 0         0.00             0.0             0
# 1         0.00             2.2        710000
# 2        38.99             0.0             0
# 3         0.00             2.2             5
# 4         0.00             4.9       6710000

# %%
kmeans_df_cluster_df1.groupby(by='cluster').max()
# Out:
#           Price  Average Rating  Rating Count
# cluster
# 0         32.99             2.1          7940
# 1          0.00             4.9       2840000
# 2        109.99             4.6            76
# 3         34.49             5.0        630000
# 4          0.00             4.9       6710000

# %%
kmeans_df_cluster_df2 = execute_kmeans(df, ['Country Count', 'Average Rating', 'Rating Count'], 5)

# %%
kmeans_df_cluster_df2['cluster'].value_counts()
# Out:
# 1    795
# 2    530
# 3    234
# 4     11
# 0      1
# Name: cluster, dtype: int64

# %%
kmeans_df_cluster_df2.groupby(by='cluster').min()
# Out:
#          Country Count  Average Rating  Rating Count
# cluster
# 0                   43             4.9       6710000
# 1                    1             0.0             0
# 2                    1             2.1             5
# 3                   21             0.0             0
# 4                    8             3.5       1140000

# %%
kmeans_df_cluster_df2.groupby(by='cluster').max()
# Out:
#          Country Count  Average Rating  Rating Count
# cluster
# 0                   43             4.9       6710000
# 1                   26             2.0          7940
# 2                   21             5.0        867000
# 3                   50             5.0        954000
# 4                   50             4.9       2840000

# %% [markdown]
# #### CLASSIFICATION MODEL

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1571 entries, 0 to 1570
# Data columns (total 23 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Unnamed: 0                          1571 non-null   int64
#  1   App Name                            1571 non-null   object
#  2   Age Rating                          1571 non-null   object
#  3   Price                               1571 non-null   float64
#  4   InApp Purchase                      1571 non-null   bool
#  5   Average Rating                      1571 non-null   float64
#  6   Rating Count                        1571 non-null   int64
#  7   App Link                            1571 non-null   object
#  8   Last Updated                        1571 non-null   object
#  9   Released Date                       1317 non-null   object
#  10  Downloads                           1571 non-null   object
#  11  Version                             1570 non-null   object
#  12  Application Type                    1571 non-null   object
#  13  Country Count                       1571 non-null   int64
#  14  Countries                           1571 non-null   object
#  15  Service Type                        1571 non-null   object
#  16  is_available_in_multiple_countries  1571 non-null   bool
#  17  is_version_app_dependent            1571 non-null   bool
#  18  Rating Count Range                  1571 non-null   object
#  19  Price Category                      1571 non-null   object
#  20  is_updated_this_year                1571 non-null   object
#  21  is_app_ever_updated                 1571 non-null   object
#  22  App Grade                           1571 non-null   object
# dtypes: bool(3), float64(2), int64(3), object(15)
# memory usage: 250.2+ KB

# %%
def draw_heatmap():
    df_num = df[['Price', 'Rating Count', 'Country Count', 'Average Rating']]
    ax = sbn.heatmap( df_num.corr(method='spearman'), cmap = 'rainbow', annot=True)
    fig = pyplot.gcf()
    fig.set_size_inches(8, 6)

# %%
draw_heatmap()

# %% [markdown]
# ##### Rating count is a good variable to determine the average rating based on correlation

# %%
def create_ordinal_fields(df):
    age_rating_map = {'PEGI 3' : 0, 'PEGI 12' : 1 , 'PEGI 18' : 2, 'PEGI 16' : 3, 'None': 4 }
    app_grading_map = {'EXCELLENT' : 4, 'VERY GOOD' : 3, 'GOOD' : 2, 'FAIR' : 1, 'BAD' : 0 }
    rating_count_map = {'0' : 0, '1+' : 1, '5+' : 2, '10+' : 3, '50+' : 4, '100+' : 5, '500+' : 6, '1,000+' : 7,
                       '5,000+' : 8, '10,000+' : 9, '50,000+' : 10, '100,000+' : 11, '500,000+' : 12, '1,000,000+': 13,
                       '5,000,000+' : 14, '10,000,000+' : 15, '50,000,000+' : 16, '100,000,000+' : 17,
                        '500,000,000+' : 18, '1,000,000,000+' : 19}
    download_count_map = {'0' : 0, '1+' : 1, '5+' : 2, '10+' : 3, '50+' : 4, '100+' : 5, '500+' : 6, '1,000+' : 7,
                       '5,000+' : 8, '10,000+' : 9, '50,000+' : 10, '100,000+' : 11, '500,000+' : 12, '1,000,000+': 13,
                          '5,000,000+' : 14, '10,000,000+' : 15, '50,000,000+' : 16, '100,000,000+' : 17, 
                         '500,000,000+' : 18, '1,000,000,000+' : 19}
    price_map = {np.nan : 0, 'None' : 0, '0+' : 1, '1+' : 1, '5+' : 2, '10+' : 3, '50+' : 4, '100+' : 5, '500+' : 6}
    inapp_purchase_map = {True : 1, False : 0}
    service_type_map = {'PAID' : 1, 'FREE' : 0}
    app_type_map = {'MEDICAL' : 1, 'HEALTH AND FITNESS' : 0}
    english_supported_map = {True : 1, False : 0}
    available_in_multiple_countries = {True : 1, False : 0}
    version_app_dependent_map = {True : 1, False : 0}
    app_ever_updated_map = {True : 1, False : 0}
    updated_this_year_map = {True : 1, False : 0}
    df['Age Rating Ord'] = df['Age Rating'].replace(age_rating_map)
    df['InApp Purchase Ord'] = df['InApp Purchase'].replace(inapp_purchase_map)
#     df['is_english_supported Ord'] = df['InApp Purchase'].replace(english_supported_map)
    df['is_available_in_multiple_countries Ord'] = df['is_available_in_multiple_countries'].replace(available_in_multiple_countries)
    df['is_version_app_dependent Ord'] = df['is_version_app_dependent'].replace(version_app_dependent_map)
    df['is_app_ever_updated Ord'] = df['is_app_ever_updated'].replace(app_ever_updated_map)
    df['is_updated_this_year Ord'] = df['is_updated_this_year'].replace(updated_this_year_map)
    df['App Grade Ord'] = df['App Grade'].replace(app_grading_map)
    df['Service Type Ord'] = df['Service Type'].replace(service_type_map)
    df['Rating Count Range Ord'] = df['Rating Count Range'].replace(rating_count_map)
    df['App Type Ord'] = df['Application Type'].replace(app_type_map)
    df['Price Category Ord'] = df['Price Category'].replace(price_map)
    df['Downloads Ord'] = df['Downloads'].replace(download_count_map)
    return df

# %%
updated_df = create_ordinal_fields(df.copy())

# %%
def draw_heatmap(df):
    df_num = df[['Price Category Ord', 'Downloads Ord','is_updated_this_year Ord', 
                 'is_available_in_multiple_countries Ord', 'InApp Purchase Ord', 'is_app_ever_updated Ord', 
                 'is_version_app_dependent Ord','Service Type Ord','Rating Count Range Ord', 'App Type Ord', 
                 'Age Rating Ord','App Grade Ord']]
    ax = sbn.heatmap( df_num.corr(method='spearman'), cmap = 'rainbow', annot=True)
    fig = pyplot.gcf()
    fig.set_size_inches(18, 8)
    font = {'family': 'Times New Roman','color':  'black','weight': 'bold','size': 16}
    pyplot.xlabel('Correlation map for Android dataset features', fontdict=font)

# %%
draw_heatmap(updated_df)

# %%
def get_top_features(no_of_features, X, Y):
    selector = SelectKBest(chi2, k="all") 
    selector.fit(X[target_attributes], Y)
    scores = (selector.scores_)
    argument_sort = list(np.argsort(scores))
    selected_attributes, selected_attribute_scores = [], []
    for i in range(len(target_attributes)-no_of_features,len(target_attributes)):
        value = argument_sort[i]
        selected_attributes.append(target_attributes[value])
        selected_attribute_scores.append(scores[value])
    return selected_attributes, selected_attribute_scores

# %%
target_attributes = ['Price Category Ord', 'Rating Count Range Ord', 'Downloads Ord', 'Age Rating Ord',
                     'InApp Purchase Ord', 'is_available_in_multiple_countries Ord', 'Service Type Ord',
                     'App Type Ord', 'is_version_app_dependent Ord', 'is_app_ever_updated Ord',
                     'is_updated_this_year Ord' ]

# %%
selected_attributes, selected_attributes_score = get_top_features(7, 
                                            updated_df, 
                                             updated_df['App Grade Ord'])

# %%
selected_attributes_score
# Out:
# [21.123366553513694,
#  58.5693397776275,
#  80.10541044015282,
#  136.65017835316348,
#  149.1295605412093,
#  370.41820810996825,
#  6168.013261637572]

# %%
selected_attributes
# Out:
# ['is_version_app_dependent Ord',
#  'Age Rating Ord',
#  'App Type Ord',
#  'is_available_in_multiple_countries Ord',
#  'InApp Purchase Ord',
#  'Downloads Ord',
#  'Rating Count Range Ord']

# %%
sbn.barplot(x=selected_attributes, y=selected_attributes_score)
set_plot_labels('Attributes', 'Scores', 'large')
fig = pyplot.gcf()
fig.set_size_inches(8, 6)
pyplot.xlabel('SelectKBest for top 7 features (Android)')
# Out:
# Text(0.5, 0, 'SelectKBest for top 7 features (Android)')

# %%
filtered_attributes = ['Rating Count Range Ord', 'Downloads Ord', 'InApp Purchase Ord',
                       'is_available_in_multiple_countries Ord', 'App Type Ord']

# %%
updated_df['App Grade Ord'].value_counts()
# Out:
# 0    869
# 4    277
# 3    197
# 2    172
# 1     56
# Name: App Grade Ord, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(updated_df[filtered_attributes],
                                                    updated_df['App Grade Ord'], test_size=0.30, random_state=42)

# %%
y_train.value_counts()
# Out:
# 0    599
# 4    192
# 2    135
# 3    129
# 1     44
# Name: App Grade Ord, dtype: int64

# %%
y_test.value_counts()
# Out:
# 0    270
# 4     85
# 3     68
# 2     37
# 1     12
# Name: App Grade Ord, dtype: int64

# %%
def oversample_train_data(X_train, y_train):
    oversampler = SMOTE()
    oversampled_df_X, oversampled_df_Y = oversampler.fit_resample(X_train, y_train)
    return oversampled_df_X, oversampled_df_Y

# %%
oversampled_df_X, oversampled_df_Y = oversample_train_data(X_train, y_train)

# %%
oversampled_df_Y.value_counts()
# Out:
# 0    599
# 4    599
# 3    599
# 1    599
# 2    599
# Name: App Grade Ord, dtype: int64

# %%
def create_and_fit_model(X, Y):
    clf = DecisionTreeClassifier()
    fitted_model = clf.fit(X,Y)
    print('Training score => ', fitted_model.score(X, Y))
    return fitted_model

# %%
fitted_model = create_and_fit_model(oversampled_df_X[filtered_attributes], oversampled_df_Y)
# Out:
# Training score =>  0.7666110183639399

# %%
def compute_validation_accuracy_and_classification_report(test_X, test_Y):
    y_pred = fitted_model.predict(test_X)
    print('Validation accuracy => ', fitted_model.score(test_X, test_Y))
    target_names = ['BAD','FAIR','GOOD', 'VERY GOOD', 'EXCELLENT']
    print(classification_report(test_Y, y_pred, target_names=target_names))

# %%
compute_validation_accuracy_and_classification_report(X_test[filtered_attributes], y_test)
# Out:
# Validation accuracy =>  0.7521186440677966
#               precision    recall  f1-score   support
#
#          BAD       1.00      0.93      0.96       270
#         FAIR       0.26      0.75      0.39        12
#         GOOD       0.37      0.70      0.49        37
#    VERY GOOD       0.46      0.19      0.27        68
#    EXCELLENT       0.63      0.66      0.64        85
#
#     accuracy                           0.75       472
#    macro avg       0.55      0.65      0.55       472
# weighted avg       0.79      0.75      0.75       472

# %%
df['Application Type'].value_counts()
# Out:
# MEDICAL               895
# HEALTH AND FITNESS    676
# Name: Application Type, dtype: int64

# %%
895/(895+676)
# Out:
# 0.5697008274984087

# %%
676/(895+676)
# Out:
# 0.43029917250159133

# %%
draw_count_plot_with_annot(df, 'Application Type', 'Android mHealth Application Type', 
                           'Application Count', fig_size=(5,6), annotCount=False)

# %%
draw_count_plot_with_annot(df, 'Rating Count Range', 'Android mHealth Average Rating Count', 
                           'Android mHealth Application Count',fig_size=(15,6), annotCount=True,
                           order=rating_count_range_order)

# %%
sbn.scatterplot(data=df, y='Rating Count', x='Average Rating')
fig = pyplot.gcf()
fig.set_size_inches(12, 8)
pyplot.xlabel('Android mHealth Apps Average Rating')
pyplot.ylabel('Android mHealth Apps Rating Count')
pyplot.show()

# %%
sbn.catplot(data=df, x='App Grade', y='Price',
            height=5, aspect=1.5, color="#AD7B1D", order=app_grade_order)
set_plot_labels('Android mHealth App Rating Category', 'Price (£)', 'large')

# %%
df['Price'].max()
# Out:
# 109.99

# %%
df[df['Price']==df['Price'].max()]
# Out:
#      Unnamed: 0         App Name Age Rating   Price  InApp Purchase  \
# 496        2431  Care-Ace Tablet     PEGI 3  109.99           False
#
#      Average Rating  Rating Count  \
# 496             0.0             0
#
#                                               App Link  Last Updated  \
# 496  https://play.google.com/store/apps/details?id=...  Jun 22, 2022
#
#     Released Date Downloads Version Application Type  Country Count Countries  \
# 496  Jul 15, 2019      500+   1.03J          MEDICAL              1        BE
#
#     Service Type  is_available_in_multiple_countries  \
# 496         PAID                               False
#
#      is_version_app_dependent Rating Count Range Price Category  \
# 496                     False                  0           100+
#
#     is_updated_this_year is_app_ever_updated App Grade
# 496                 True                True       BAD

# %%
df[df['Rating Count']==df['Rating Count'].max()]
# Out:
#      Unnamed: 0                        App Name Age Rating  Price  \
# 897        6044  Period Calendar Period Tracker     PEGI 3    0.0
#
#      InApp Purchase  Average Rating  Rating Count  \
# 897            True             4.9       6710000
#
#                                               App Link  Last Updated  \
# 897  https://play.google.com/store/apps/details?id=...  Jun 10, 2022
#
#     Released Date     Downloads             Version    Application Type  \
# 897  Mar 16, 2012  100,000,000+  Varies with device  HEALTH AND FITNESS
#
#      Country Count                                          Countries  \
# 897             43  SE,GF,GP,DK,GR,PL,RE,PM,AT,MC,MT,BL,LU,MQ,MF,C...
#
#     Service Type  is_available_in_multiple_countries  \
# 897         FREE                                True
#
#      is_version_app_dependent Rating Count Range Price Category  \
# 897                      True         5,000,000+              0
#
#     is_updated_this_year is_app_ever_updated  App Grade
# 897                 True                True  EXCELLENT

# %%
len(df['App Name'].unique())
# Out:
# 1566

# %%
df[df['App Grade']=='GOOD']['Price'].max()
# Out:
# 64.99

# %%
df[['InApp Purchase']].value_counts()
# Out:
# InApp Purchase
# False             951
# True              620
# dtype: int64

# %%
951/(951+620)
# Out:
# 0.6053469127943985

# %%
draw_count_plot_with_annot(df, 'is_available_in_multiple_countries', 'Android is available in multiple countries?',
                           'Android mHealth Application Count',fig_size=(15,6),
                           annotCount=False, order=[True, False])

# %%
df[df['Downloads']==0]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, App Name, Age Rating, Price, InApp Purchase, Average Rating, Rating Count, App Link, Last Updated, Released Date, Downloads, Version, Application Type, Country Count, Countries, Service Type, is_available_in_multiple_countries, is_version_app_dependent, Rating Count Range, Price Category, is_updated_this_year, is_app_ever_updated, App Grade]
# Index: []

# %%
df['Downloads'].unique()
# Out:
# array(['1,000,000+', '100,000+', '50,000+', '10,000,000+', '500+',
#        '5,000,000+', '10,000+', '5,000+', '1,000+', '500,000+', '10+',
#        '100+', '50,000,000+', '50+', '1+', '5+', '100,000,000+',
#        '500,000,000+', '1,000,000,000+'], dtype=object)

# %%
df[(df['Downloads']=='1+') | (df['Downloads']=='5+')| (df['Downloads']=='10+')]
# Out:
#       Unnamed: 0                                           App Name  \
# 68            68                                     Sunna Médecine
# 182          407                                 MyVisualField Test
# 186          413  Pocket Atlas of Emergency Ultrasound, 2nd Edition
# 210          447                                              Mapar
# 222          461  Morgan And Mikhail's Clinical Anesthesiology, 6/E
# 226          481                                   Memória Auditiva
# 240          533                                        SpeakUp Too
# 243          543                      Okell Medicine: Notes & Audio
# 265          707                          inomed eApplication notes
# 316          813                                        OmaTTBotnia
# 427         1527                     MedicAlert Virtual Wallet Card
# 524         2506                                           ThrustMe
# 622         3828                                    ICD 10 & ICD 11
# 630         3859                                     Blood pressure
# 761         5098      Snore detection Full | Adapt it to your needs
# 766         5104  Snore detection ad Free | Adjust it to you sno...
# 863         5651                                   Rapid Checkpoint
# 955         6102                       The Shodan by Shihan Collins
# 1016        6194                                  Yoga Nidra France
# 1166        6850                                  DW Meditation Pro
# 1239        7512                      Health Services Complications
# 1249        7540                      Homeopathy hindi saral Upchar
#
#      Age Rating  Price  InApp Purchase  Average Rating  Rating Count  \
# 68       PEGI 3   0.99           False             0.0             0
# 182      PEGI 3  10.49           False             0.0             0
# 186      PEGI 3  56.99           False             0.0             0
# 210      PEGI 3  50.99           False             0.0             0
# 222      PEGI 3  69.99           False             0.0             0
# 226      PEGI 3   8.49           False             0.0             0
# 240      PEGI 3   2.39           False             0.0             0
# 243      PEGI 3   1.29           False             0.0             0
# 265      PEGI 3  42.99           False             0.0             0
# 316      PEGI 3   0.00           False             0.0             0
# 427      PEGI 3   4.99           False             0.0             0
# 524      PEGI 3  17.99           False             0.0             0
# 622      PEGI 3   4.49           False             0.0             0
# 630      PEGI 3   5.49           False             0.0             0
# 761      PEGI 3   8.99           False             0.0             0
# 766      PEGI 3   1.29           False             0.0             0
# 863      PEGI 3   0.00           False             0.0             0
# 955      PEGI 3   5.49           False             0.0             0
# 1016     PEGI 3   4.09           False             0.0             0
# 1166     PEGI 3  40.99           False             0.0             0
# 1239     PEGI 3   1.49           False             0.0             0
# 1249     PEGI 3   0.29           False             0.0             0
#
#                                                App Link  Last Updated  \
# 68    https://play.google.com/store/apps/details?id=...   Mar 8, 2022
# 182   https://play.google.com/store/apps/details?id=...   Jul 2, 2021
# 186   https://play.google.com/store/apps/details?id=...  Mar 30, 2021
# 210   https://play.google.com/store/apps/details?id=...  Jan 25, 2022
# 222   https://play.google.com/store/apps/details?id=...  Mar 30, 2021
# 226   https://play.google.com/store/apps/details?id=...  May 30, 2022
# 240   https://play.google.com/store/apps/details?id=...   Jun 9, 2022
# 243   https://play.google.com/store/apps/details?id=...  Mar 15, 2022
# 265   https://play.google.com/store/apps/details?id=...  Mar 10, 2021
# 316   https://play.google.com/store/apps/details?id=...  May 19, 2022
# 427   https://play.google.com/store/apps/details?id=...  Feb 15, 2022
# 524   https://play.google.com/store/apps/details?id=...  Jan 11, 2021
# 622   https://play.google.com/store/apps/details?id=...  Dec 15, 2020
# 630   https://play.google.com/store/apps/details?id=...   Oct 7, 2019
# 761   https://play.google.com/store/apps/details?id=...  Jan 27, 2021
# 766   https://play.google.com/store/apps/details?id=...  Jan 30, 2021
# 863   https://play.google.com/store/apps/details?id=...   Jun 8, 2022
# 955   https://play.google.com/store/apps/details?id=...  Jun 16, 2022
# 1016  https://play.google.com/store/apps/details?id=...  Apr 28, 2022
# 1166  https://play.google.com/store/apps/details?id=...   Sep 4, 2021
# 1239  https://play.google.com/store/apps/details?id=...  Jun 18, 2022
# 1249  https://play.google.com/store/apps/details?id=...  Jun 23, 2022
#
#      Released Date Downloads             Version    Application Type  \
# 68     Mar 8, 2022       10+               1.0.0             MEDICAL
# 182    Oct 4, 2019       10+               1.0.5             MEDICAL
# 186   Sep 23, 2018       10+                 1.1             MEDICAL
# 210    Sep 7, 2021       10+               1.1.6             MEDICAL
# 222   Feb 13, 2019       10+                 1.1             MEDICAL
# 226   May 30, 2022        1+               1.0.0             MEDICAL
# 240    Jun 9, 2022        1+             1.0.0.0             MEDICAL
# 243   Mar 15, 2022       10+                 1.0             MEDICAL
# 265   Mar 25, 2021       10+                 1.0             MEDICAL
# 316            NaN       10+              0.10.0             MEDICAL
# 427   Feb 15, 2022       10+               1.0.6             MEDICAL
# 524   Jan 11, 2021       10+                 1.0             MEDICAL
# 622   Dec 15, 2020       10+                 1.0             MEDICAL
# 630    Oct 7, 2019        5+                 1.0             MEDICAL
# 761   Oct 30, 2018        5+           3.01.00.2             MEDICAL
# 766   Oct 30, 2018        5+           3.01.00.2             MEDICAL
# 863            NaN       10+                1.11             MEDICAL
# 955   Jun 16, 2022       10+               1.0.0  HEALTH AND FITNESS
# 1016  Apr 28, 2022       10+                 1.2  HEALTH AND FITNESS
# 1166  Sep 19, 2020        5+  Varies with device  HEALTH AND FITNESS
# 1239  Jun 12, 2022       10+  Varies with device  HEALTH AND FITNESS
# 1249  May 25, 2022       10+                 1.6  HEALTH AND FITNESS
#
#       Country Count                                          Countries  \
# 68               45  FO,PT,HR,SM,GI,FI,EE,HU,SI,GL,IE,RO,SK,PF,SJ,I...
# 182               1                                                 IT
# 186               1                                                 IT
# 210               1                                                 IT
# 222               1                                                 IT
# 226               4                                        SM,GI,VA,MC
# 240               4                                        SM,GI,VA,MC
# 243               4                                        SM,GI,VA,MC
# 265               1                                                 DE
# 316               1                                                 FI
# 427               2                                              IE,GB
# 524               1                                                 BE
# 622               1                                                 AT
# 630               1                                                 AT
# 761               1                                                 SE
# 766               1                                                 SE
# 863               1                                                 GR
# 955               4                                        SE,MC,VA,SM
# 1016              5                                     FR,MC,VA,GI,SM
# 1166              1                                                 GR
# 1239              4                                        MC,VA,GI,SM
# 1249              4                                        MC,VA,GI,SM
#
#      Service Type  is_available_in_multiple_countries  \
# 68           PAID                                True
# 182          PAID                               False
# 186          PAID                               False
# 210          PAID                               False
# 222          PAID                               False
# 226          PAID                                True
# 240          PAID                                True
# 243          PAID                                True
# 265          PAID                               False
# 316          FREE                               False
# 427          PAID                                True
# 524          PAID                               False
# 622          PAID                               False
# 630          PAID                               False
# 761          PAID                               False
# 766          PAID                               False
# 863          FREE                               False
# 955          PAID                                True
# 1016         PAID                                True
# 1166         PAID                               False
# 1239         PAID                                True
# 1249         PAID                                True
#
#       is_version_app_dependent Rating Count Range Price Category  \
# 68                       False                  0             0+
# 182                      False                  0            10+
# 186                      False                  0            50+
# 210                      False                  0            50+
# 222                      False                  0            50+
# 226                      False                  0             5+
# 240                      False                  0             1+
# 243                      False                  0             1+
# 265                      False                  0            10+
# 316                      False                  0              0
# 427                      False                  0             1+
# 524                      False                  0            10+
# 622                      False                  0             1+
# 630                      False                  0             5+
# 761                      False                  0             5+
# 766                      False                  0             1+
# 863                      False                  0              0
# 955                      False                  0             5+
# 1016                     False                  0             1+
# 1166                      True                  0            10+
# 1239                      True                  0             1+
# 1249                     False                  0             0+
#
#      is_updated_this_year is_app_ever_updated App Grade
# 68                  False               False       BAD
# 182                 False                True       BAD
# 186                 False                True       BAD
# 210                  True                True       BAD
# 222                 False                True       BAD
# 226                 False               False       BAD
# 240                 False               False       BAD
# 243                 False               False       BAD
# 265                 False                True       BAD
# 316                  True                True       BAD
# 427                 False               False       BAD
# 524                 False               False       BAD
# 622                 False               False       BAD
# 630                 False               False       BAD
# 761                 False                True       BAD
# 766                 False                True       BAD
# 863                  True                True       BAD
# 955                 False               False       BAD
# 1016                False               False       BAD
# 1166                False                True       BAD
# 1239                 True                True       BAD
# 1249                 True                True       BAD

# %%
draw_count_plot_with_annot(df, 'App Grade', 'Android App Performance (Service Type)',
                           'Android mHealth Application Count',hue= 'Service Type', fig_size=(8,5),
                           order=app_grade_order,
                           annotCount=False, palette=['#1C8BAD', 'red'])

# %%
draw_count_plot_with_annot(df, 'App Grade', 'Android App Performance (Service Type)',
                           'Android mHealth Application Count',hue= 'InApp Purchase', fig_size=(8,5),
                           order=app_grade_order,
                           annotCount=False, palette=['#1C8BAD', 'red'])

# %%
df['InApp Purchase']

# %%
df[df['App Grade'].isin(['VERY GOOD', 'EXCELLENT'])]['InApp Purchase'].value_counts()
# Out:
# True     317
# False    157
# Name: InApp Purchase, dtype: int64

# %%
df['InApp Purchase'].value_counts()
# Out:
# False    951
# True     620
# Name: InApp Purchase, dtype: int64

# %%
398/(398+248)
# Out:
# 0.6160990712074303

# %%
draw_count_plot_with_annot(df, 'Rating Count Range', 'App Grade (multiple languages supported)',
                           'Android mHealth Application Count',hue= 'Service Type', fig_size=(18,6), 
                           
     order=rating_count_range_order, annotCount=False, palette=['#1C8BAD', 'red'])

# %%
draw_count_plot_with_annot(df, 'App Grade', 'App Grade (multiple languages supported)',
                           'Ios mHealth Application Count',hue= 'Application Type', fig_size=(18,6), 
                           
     order=app_grade_order, annotCount=False, palette=['#1C8BAD', 'red'])
