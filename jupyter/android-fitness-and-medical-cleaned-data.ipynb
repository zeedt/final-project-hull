# %%
import pandas as pd
import numpy as np
import glob
import os

# %%
pd. set_option("display.max_columns", None)

# %%
path = './../android'
android_files = glob.glob(os.path.join(path , "*.csv"))
dfs = []
for filename in android_files:
    df = pd.read_csv(filename)
    dfs.append(df)

df = pd.concat(dfs, axis=0, ignore_index=True)

# %%
df
# Out:
#                                               App Name Age Rating  Price  \
# 0                        Fitify: Fitness, Home Workout     PEGI 3      0
# 1                        Lose Belly Fat  - Abs Workout     PEGI 3      0
# 2                            Lose Weight App for Women     PEGI 3      0
# 3                        Running App - GPS Run Tracker     PEGI 3      0
# 4                          Nike Training Club: Fitness     PEGI 3      0
# ..                                                 ...        ...    ...
# 186  Push Doctor - Online Doctor Appointments & Advice     PEGI 3      0
# 187   Instant Body Temperature Checker : Fever Tracker     PEGI 3      0
# 188                                      Joii Pet Care     PEGI 3      0
# 189                                  Pregnancy Tracker     PEGI 3      0
# 190                                            PetsApp     PEGI 3      0
#
#      InApp Purchase  Average Rating Rating Count  \
# ...
